# %%
from matplotlib.image import imread
import numpy as np
import matplotlib.pyplot as plt

img = imread("images/graphics.png")
plt.figure()
plt.imshow(img)

# %%
rgb_weights = [0.2989, 0.5870, 0.1140]
grayscale_image = np.dot(img[...,:3], rgb_weights)
plt.figure()
plt.imshow(grayscale_image, cmap="gray")
grayscale_image.shape
# Out:
# (512, 512)

# %%
grayscale_image_transformed = np.fft.fft2(grayscale_image)
print(grayscale_image_transformed)
final = np.fft.ifft2(grayscale_image_transformed).real
plt.figure()
plt.imshow(final, cmap="gray")
# Out:
# [[ 57522.88182392    +0.j          -3212.32486557 +2153.18540287j
#    -2730.77689373  +564.59114564j ...  -1507.44965493  -310.42337754j
#    -2730.77689373  -564.59114564j  -3212.32486557 -2153.18540287j]
#  [-14540.99746267-17389.92476266j   2940.26938452 +1974.87697815j
#     3909.50150488 -1229.63566438j ...    366.31817478  -213.95159315j
#     2562.63583462   -91.65538326j   2796.04856873  +216.38894706j]
#  [  4941.2670497  +1845.09378627j   1378.70540221 -2323.35606962j
#    -4343.75766774 +1509.62898864j ...    131.49183722  -369.66212771j
#    -1855.58663105 -1776.82081521j  -4348.83191603 -1001.44830767j]
#  ...
#  [ -3679.7421491  +5234.89112274j   2083.74657739 -1772.96196553j
#     1010.0685052  -3021.11505766j ...    -65.13690875 +1807.24116896j
#     3349.04898263   -19.35786571j  -2194.94749805  -478.63018605j]
#  [  4941.2670497  -1845.09378627j  -4348.83191603 +1001.44830767j
#    -1855.58663105 +1776.82081521j ...   -251.51749039  -346.55660538j
#    -4343.75766774 -1509.62898864j   1378.70540221 +2323.35606962j]
#  [-14540.99746267+17389.92476266j   2796.04856873  -216.38894706j
#     2562.63583462   +91.65538326j ...   2131.50718142  -211.93296538j
#     3909.50150488 +1229.63566438j   2940.26938452 -1974.87697815j]]

# %%
np.fft.fft(np.array([1,1,1,1,0,0,0,0]))
# Out:
# array([4.+0.j        , 1.-2.41421356j, 0.+0.j        , 1.-0.41421356j,
#        0.+0.j        , 1.+0.41421356j, 0.+0.j        , 1.+2.41421356j])
